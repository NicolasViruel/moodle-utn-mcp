# %% [markdown]
# <div style="background-color:#001855; color:#ffffff; padding:22px 18px; border-radius:10px; text-align:center; font-family:'Segoe UI',Arial,sans-serif;">
#   <div style="font-size:0.85rem; font-weight:bold; letter-spacing:0.04em; margin-bottom:8px;">
#     INTRODUCCIÓN AL ANÁLISIS DE DATOS · TUPaD
#   </div>
#   <h1 style="font-size:2rem; line-height:1.35; margin:0;">💎 Exploración inicial con Diamonds</h1>
#   <p style="font-size:1.05rem; line-height:1.6; margin:10px 0 0;">
#     Semana 3 · Práctica obligatoria · Opción Python
#   </p>
# </div>
#
# <div style="display:inline-block; background-color:#e3f2fd; border:1px solid #bbdefb; border-radius:20px; padding:5px 10px; margin-top:14px; color:#1565c0; font-size:0.85rem; font-weight:bold; font-family:'Segoe UI',Arial,sans-serif;">
#   OBLIGATORIA · ELEGÍ UNA SOLA OPCIÓN
# </div>
#
# <div style="background-color:#fff3e0; border:1px solid #ffcc80; border-radius:8px; padding:12px 14px; margin-top:14px; font-family:'Segoe UI',Arial,sans-serif; color:#e65100; line-height:1.7;">
#   ⏱️ <strong>Tiempo estimado:</strong> 1 pomodoro (20 minutos).
# </div>

# %% [markdown]
# <div style="font-family:'Segoe UI',Arial,sans-serif; color:#1a237e; line-height:1.7;">
#   <h2 style="color:#1565c0; font-size:1.35rem;">🎯 Propósito de la práctica</h2>
#   <p>
#     En esta práctica vas a aplicar el procedimiento trabajado en la Actividad 1
#     sobre el dataset <strong>Diamonds</strong>. El objetivo es reconocer su estructura,
#     obtener un resumen descriptivo inicial y redactar dos interpretaciones breves.
#   </p>
#   <p>
#     No es necesario completar las opciones Python y R. Realizá solamente el notebook
#     correspondiente al lenguaje que elegiste para tu recorrido principal.
#   </p>
# </div>
#
# <div style="background-color:#e3f2fd; border:1px solid #bbdefb; border-radius:8px; padding:12px 14px; font-family:'Segoe UI',Arial,sans-serif; color:#1a237e; line-height:1.7;">
#   📌 <strong>Importante:</strong> el notebook intenta cargar la versión completa de
#   Diamonds desde una fuente pública. Si la conexión no está disponible, utiliza
#   automáticamente una muestra local incluida en el archivo.
# </div>

# %% [markdown]
# <div style="font-family:'Segoe UI',Arial,sans-serif; color:#1a237e; line-height:1.7;">
#   <h2 style="color:#1565c0; font-size:1.35rem;">1. Preparar y cargar los datos</h2>
#   <p>
#     Ejecutá la siguiente celda. Intentará cargar el dataset completo. Si no puede
#     acceder a Internet, construirá una muestra local con las mismas variables principales.
#   </p>
# </div>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv"

columnas = ["carat", "cut", "color", "clarity", "depth", "table", "price", "x", "y", "z"]
muestra_local = [[0.23, 'Ideal', 'E', 'SI2', 61.5, 55, 326, 3.95, 3.98, 2.43], [0.21, 'Premium', 'E', 'SI1', 59.8, 61, 326, 3.89, 3.84, 2.31], [0.23, 'Good', 'E', 'VS1', 56.9, 65, 327, 4.05, 4.07, 2.31], [0.29, 'Premium', 'I', 'VS2', 62.4, 58, 334, 4.2, 4.23, 2.63], [0.31, 'Good', 'J', 'SI2', 63.3, 58, 335, 4.34, 4.35, 2.75], [0.24, 'Very Good', 'J', 'VVS2', 62.8, 57, 336, 3.94, 3.96, 2.48], [0.24, 'Very Good', 'I', 'VVS1', 62.3, 57, 336, 3.95, 3.98, 2.47], [0.26, 'Very Good', 'H', 'SI1', 61.9, 55, 337, 4.07, 4.11, 2.53], [0.22, 'Fair', 'E', 'VS2', 65.1, 61, 337, 3.87, 3.78, 2.49], [0.23, 'Very Good', 'H', 'VS1', 59.4, 61, 338, 4.0, 4.05, 2.39], [0.3, 'Good', 'J', 'SI1', 64.0, 55, 339, 4.25, 4.28, 2.73], [0.23, 'Ideal', 'J', 'VS1', 62.8, 56, 340, 3.93, 3.9, 2.46], [0.22, 'Premium', 'F', 'SI1', 60.4, 61, 342, 3.88, 3.84, 2.33], [0.31, 'Ideal', 'J', 'SI2', 62.2, 54, 344, 4.35, 4.37, 2.71], [0.2, 'Premium', 'E', 'SI2', 60.2, 62, 345, 3.79, 3.75, 2.27], [0.32, 'Premium', 'E', 'I1', 60.9, 58, 345, 4.38, 4.42, 2.68], [0.3, 'Ideal', 'I', 'SI2', 62.0, 54, 348, 4.31, 4.34, 2.68], [0.3, 'Good', 'J', 'SI1', 63.4, 54, 351, 4.23, 4.29, 2.7], [0.3, 'Good', 'J', 'SI1', 63.8, 56, 351, 4.23, 4.26, 2.71], [0.3, 'Very Good', 'J', 'SI1', 62.7, 59, 351, 4.21, 4.27, 2.66], [0.4, 'Ideal', 'G', 'VS2', 61.3, 56, 702, 4.78, 4.81, 2.94], [0.5, 'Premium', 'F', 'SI1', 60.7, 59, 1120, 5.16, 5.12, 3.12], [0.6, 'Very Good', 'H', 'VS1', 62.1, 57, 1540, 5.42, 5.47, 3.38], [0.7, 'Ideal', 'G', 'VS2', 61.8, 55, 2360, 5.7, 5.73, 3.53], [0.8, 'Premium', 'F', 'SI1', 60.9, 59, 3150, 6.03, 5.98, 3.66], [0.9, 'Good', 'H', 'VS2', 63.0, 58, 3820, 6.1, 6.06, 3.83], [1.0, 'Ideal', 'G', 'SI1', 61.7, 56, 5150, 6.39, 6.43, 3.96], [1.1, 'Very Good', 'I', 'VS1', 62.4, 58, 5680, 6.55, 6.6, 4.1], [1.2, 'Premium', 'H', 'SI2', 60.8, 60, 6420, 6.86, 6.81, 4.16], [1.3, 'Ideal', 'F', 'VS2', 61.9, 55, 8120, 7.02, 7.06, 4.36]]

try:
    df = pd.read_csv(url)
    fuente = "dataset completo cargado desde la fuente pública"
except Exception:
    df = pd.DataFrame(muestra_local, columns=columnas)
    fuente = "muestra local incluida en el notebook"

print("Fuente utilizada:", fuente)
print("Datos cargados correctamente.")
# Out:
# Fuente utilizada: dataset completo cargado desde la fuente pública
# Datos cargados correctamente.

# %% [markdown]
# <div style="font-family:'Segoe UI',Arial,sans-serif; color:#1a237e; line-height:1.7;">
#   <h2 style="color:#1565c0; font-size:1.35rem;">2. Observar las primeras filas</h2>
#   <p>Utilizá `head()` para observar los primeros registros.</p>
#   <details style="background-color:#ffffff; border:1px solid #cfd8dc; border-radius:8px; padding:10px 12px;">
#     <summary style="color:#1565c0; font-weight:bold; cursor:pointer;">Ver una pista</summary>
#     <pre style="margin-bottom:0;"><code>df.head()</code></pre>
#   </details>
# </div>

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# <div style="font-family:'Segoe UI',Arial,sans-serif; color:#1a237e; line-height:1.7;">
#   <h2 style="color:#1565c0; font-size:1.35rem;">3. Consultar las dimensiones</h2>
#   <p>Averiguá cuántas filas y columnas tiene el DataFrame.</p>
#   <details style="background-color:#ffffff; border:1px solid #cfd8dc; border-radius:8px; padding:10px 12px;">
#     <summary style="color:#1565c0; font-weight:bold; cursor:pointer;">Ver una pista</summary>
#     <pre style="margin-bottom:0;"><code>df.shape</code></pre>
#   </details>
# </div>

# %%
filas, columnas = df.shape
print("Cantidad de filas:", filas)
print("Cantidad de columnas:", columnas)
# Out:
# Cantidad de filas: 53940
# Cantidad de columnas: 10

# %% [markdown]
# <div style="font-family:'Segoe UI',Arial,sans-serif; color:#1a237e; line-height:1.7;">
#   <h2 style="color:#1565c0; font-size:1.35rem;">4. Reconocer columnas y tipos de datos</h2>
#   <p>Consultá los nombres de las columnas y los tipos de datos.</p>
#   <details style="background-color:#ffffff; border:1px solid #cfd8dc; border-radius:8px; padding:10px 12px;">
#     <summary style="color:#1565c0; font-weight:bold; cursor:pointer;">Ver una pista</summary>
#     <pre style="margin-bottom:0;"><code>df.columns.tolist()
# df.dtypes</code></pre>
#   </details>
# </div>

# %%
print("Columnas del dataset:")
print(df.columns.tolist())

print("\nTipos de datos:")
print(df.dtypes)
# Out:
# Columnas del dataset:
# ['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y', 'z']
#
# Tipos de datos:
# carat      float64
# cut            str
# color          str
# clarity        str
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %% [markdown]
# <div style="font-family:'Segoe UI',Arial,sans-serif; color:#1a237e; line-height:1.7;">
#   <h2 style="color:#1565c0; font-size:1.35rem;">5. Obtener un resumen descriptivo</h2>
#   <p>Generá un resumen de las variables numéricas y redondeá los resultados a dos decimales.</p>
#   <details style="background-color:#ffffff; border:1px solid #cfd8dc; border-radius:8px; padding:10px 12px;">
#     <summary style="color:#1565c0; font-weight:bold; cursor:pointer;">Ver una pista</summary>
#     <pre style="margin-bottom:0;"><code>df.describe().round(2)</code></pre>
#   </details>
# </div>

# %%
df.describe().round(2)
# Out:
#           carat     depth     table     price         x         y         z
# count  53940.00  53940.00  53940.00  53940.00  53940.00  53940.00  53940.00
# mean       0.80     61.75     57.46   3932.80      5.73      5.73      3.54
# std        0.47      1.43      2.23   3989.44      1.12      1.14      0.71
# min        0.20     43.00     43.00    326.00      0.00      0.00      0.00
# 25%        0.40     61.00     56.00    950.00      4.71      4.72      2.91
# 50%        0.70     61.80     57.00   2401.00      5.70      5.71      3.53
# 75%        1.04     62.50     59.00   5324.25      6.54      6.54      4.04
# max        5.01     79.00     95.00  18823.00     10.74     58.90     31.80

# %% [markdown]
# <div style="font-family:'Segoe UI',Arial,sans-serif; color:#1a237e; line-height:1.7;">
#   <h2 style="color:#1565c0; font-size:1.35rem;">6. Revisar una variable categórica</h2>
#   <p>Obtené la frecuencia de los valores de la variable `cut`.</p>
#   <details style="background-color:#ffffff; border:1px solid #cfd8dc; border-radius:8px; padding:10px 12px;">
#     <summary style="color:#1565c0; font-weight:bold; cursor:pointer;">Ver una pista</summary>
#     <pre style="margin-bottom:0;"><code>df['cut'].value_counts()</code></pre>
#   </details>
# </div>

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %% [markdown]
# <div style="font-family:'Segoe UI',Arial,sans-serif; color:#1a237e; line-height:1.7;">
#   <h2 style="color:#1565c0; font-size:1.35rem;">7. Interpretar los resultados</h2>
#   <p>Escribí respuestas breves con tus propias palabras.</p>
#   <ol>
#     <li>¿Qué te permiten conocer las dimensiones y los tipos de datos sobre la estructura del dataset?</li>
#     <li>Elegí un resultado de <code>describe()</code> o de la frecuencia de <code>cut</code> y explicá qué información aporta.</li>
#   </ol>
# </div>

# %% [markdown]
# **Interpretación 1:** El dataset tiene **53.940 filas y 10 columnas**. Cada fila representa un diamante distinto. Las variables numéricas incluyen `carat`, `depth`, `table`, `price` y las medidas `x`, `y`, `z`; las categóricas son `cut`, `color` y `clarity`. Esto indica que puedo combinar resúmenes estadísticos (promedios, rangos) con conteos por categoría para describir el conjunto.
#
# **Interpretación 2:** En la variable **`cut`**, la categoría **Ideal** es la más frecuente (21.551 registros) y **Fair** la menos frecuente (1.610). Esto muestra que en este conjunto predominan diamantes con corte considerado de mayor calidad, aunque todavía no implica que el corte determine el precio (eso habría que analizarlo después).

# %% [markdown]
# <div style="background-color:#001855; color:#ffffff; padding:18px; border-radius:10px; text-align:center; font-family:'Segoe UI',Arial,sans-serif; line-height:1.7;">
#   <h2 style="font-size:1.4rem; margin:0;">✅ Cierre de la práctica</h2>
#   <p style="margin:10px 0 0;">
#     Inspeccionar no es solamente ejecutar comandos: también implica comprender
#     qué información aporta cada salida y expresarla con claridad.
#   </p>
# </div>
#
# <div style="background-color:#e3f2fd; border:1px solid #bbdefb; border-radius:8px; padding:12px 14px; margin-top:14px; font-family:'Segoe UI',Arial,sans-serif; color:#1a237e; line-height:1.7;">
#   🚀 <strong>Siguiente paso:</strong> continuá con la autoevaluación de cierre de la
#   Unidad N° 1 y luego aplicá este mismo procedimiento al dataset del TPI.
# </div>
