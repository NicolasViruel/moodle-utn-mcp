# %% [markdown]
# # TPI - Notebook Maestro
#
# ## Análisis de cancelaciones de reservas hoteleras
#
# **Materia:** Introducción al Análisis de Datos
#
# **Comisión:** 10
#
# **Integrantes:**
# - Nicolas Viruel
#
# **Año:** 2026

# %% [markdown]
# # 1. Definición del problema
#
# El problema seleccionado para el Trabajo Práctico Integrador consiste en analizar las cancelaciones de reservas hoteleras.
#
# Las cancelaciones representan una problemática relevante para los hoteles debido a que pueden afectar la planificación de la ocupación, la disponibilidad de habitaciones y los ingresos esperados.
#
# El objetivo inicial del análisis será estudiar las características de las reservas y buscar identificar qué factores pueden estar relacionados con la cancelación de una reserva.

# %% [markdown]
# # 2. Preguntas de análisis
#
# 1. ¿Qué **porcentaje** de reservas se cancela en el dataset?
# 2. ¿Las cancelaciones varían según el **tipo de deposito**, **canal de reserva** o **anticipación** (lead time)?
# 3. ¿Hay diferencias por **temporada**, **tipo de habitación** o **país** del cliente?
# 4. ¿Clientes **repetidos** cancelan menos que clientes nuevos?
# 5. ¿Qué variables parecen más relacionadas con `is_canceled` en una primera exploración?
# 6. ¿Qué decisiones concretas podría tomar el hotel si confirma ciertos patrones?

# %% [markdown]
# # 3. Descripción del dataset

# %% [markdown]
# # 4. Preparación y limpieza de datos

# %% [markdown]
# # 5. Análisis exploratorio de datos

# %% [markdown]
# # 6. Análisis de la variable objetivo: is_canceled
#
# La variable objetivo del problema es **is_canceled**.
#
# - `is_canceled = 0`: la reserva no fue cancelada.
# - `is_canceled = 1`: la reserva fue cancelada.
#
# El análisis buscará estudiar qué características de las reservas pueden estar relacionadas con el valor de esta variable.

# %% [markdown]
# # 7. Modelado

# %% [markdown]
# # 8. Resultados
